# %% [markdown]
# # **Assigment 5 - SPARQL Queries**
#
# ### Lucía Martín Fernández

# %%
# !pip install sparqlkernel
# Out:
# Collecting sparqlkernel
#   Using cached sparqlkernel-1.3.0.tar.gz (32 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools in /Users/lucia/mambaforge/lib/python3.10/site-packages (from sparqlkernel) (65.5.1)
# Collecting ipykernel>=4.0
#   Downloading ipykernel-6.20.1-py3-none-any.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.2/149.2 kB 1.8 MB/s eta 0:00:00a 0:00:01
# Collecting notebook
#   Downloading notebook-6.5.2-py3-none-any.whl (439 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.1/439.1 kB 8.3 MB/s eta 0:00:0000:01
# Collecting traitlets
#   Downloading traitlets-5.8.1-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.8/116.8 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: rdflib in /Users/lucia/mambaforge/lib/python3.10/site-packages (from sparqlkernel) (6.2.0)
# Collecting pygments
#   Downloading Pygments-2.14.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 18.1 MB/s eta 0:00:00a 0:00:01
# Collecting SPARQLWrapper
#   Using cached SPARQLWrapper-2.0.0-py3-none-any.whl (28 kB)
# Collecting psutil
#   Downloading psutil-5.9.4-cp36-abi3-macosx_10_9_x86_64.whl (243 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.5/243.5 kB 8.6 MB/s eta 0:00:00
# Collecting packaging
#   Downloading packaging-23.0-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 kB 2.6 MB/s eta 0:00:00
# Collecting nest-asyncio
#   Downloading nest_asyncio-1.5.6-py3-none-any.whl (5.2 kB)
# Collecting comm>=0.1.1
#   Downloading comm-0.1.2-py3-none-any.whl (6.5 kB)
# Collecting matplotlib-inline>=0.1
#   Downloading matplotlib_inline-0.1.6-py3-none-any.whl (9.4 kB)
# Collecting tornado>=6.1
#   Downloading tornado-6.2-cp37-abi3-macosx_10_9_x86_64.whl (419 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.7/419.7 kB 13.4 MB/s eta 0:00:00
# Collecting pyzmq>=17
#   Downloading pyzmq-25.0.0-cp310-cp310-macosx_10_15_universal2.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 2.6 MB/s eta 0:00:0000:0100:010m
# Collecting jupyter-client>=6.1.12
#   Downloading jupyter_client-7.4.8-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.5/133.5 kB 7.4 MB/s eta 0:00:00
# Collecting ipython>=7.23.1
#   Downloading ipython-8.8.0-py3-none-any.whl (775 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 775.8/775.8 kB 24.7 MB/s eta 0:00:00
# Collecting appnope
#   Downloading appnope-0.1.3-py2.py3-none-any.whl (4.4 kB)
# Collecting debugpy>=1.0
#   Downloading debugpy-1.6.5-cp310-cp310-macosx_11_0_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 18.6 MB/s eta 0:00:0000:0100:01
# Collecting prometheus-client
#   Downloading prometheus_client-0.15.0-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 3.3 MB/s eta 0:00:00
# Collecting ipython-genutils
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Collecting jupyter-core>=4.6.1
#   Downloading jupyter_core-5.1.3-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 kB 7.4 MB/s eta 0:00:00
# Collecting nbconvert>=5
#   Downloading nbconvert-7.2.7-py3-none-any.whl (273 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.2/273.2 kB 13.0 MB/s eta 0:00:00
# Collecting Send2Trash>=1.8.0
#   Downloading Send2Trash-1.8.0-py3-none-any.whl (18 kB)
# Collecting jinja2
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 kB 8.8 MB/s eta 0:00:00
# Collecting terminado>=0.8.3
#   Downloading terminado-0.17.1-py3-none-any.whl (17 kB)
# Collecting nbformat
#   Downloading nbformat-5.7.3-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.1/78.1 kB 5.7 MB/s eta 0:00:00
# Collecting nbclassic>=0.4.7
#   Downloading nbclassic-0.4.8-py3-none-any.whl (9.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 15.1 MB/s eta 0:00:0000:0100:01
# Collecting argon2-cffi
#   Downloading argon2_cffi-21.3.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: isodate in /Users/lucia/mambaforge/lib/python3.10/site-packages (from rdflib->sparqlkernel) (0.6.1)
# Requirement already satisfied: pyparsing in /Users/lucia/mambaforge/lib/python3.10/site-packages (from rdflib->sparqlkernel) (3.0.9)
# Collecting jedi>=0.16
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 12.5 MB/s eta 0:00:0000:0100:01
# Collecting stack-data
#   Downloading stack_data-0.6.2-py3-none-any.whl (24 kB)
# Collecting pexpect>4.3
#   Downloading pexpect-4.8.0-py2.py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.0/59.0 kB 1.5 MB/s eta 0:00:00
# Collecting decorator
#   Downloading decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Collecting backcall
#   Downloading backcall-0.2.0-py2.py3-none-any.whl (11 kB)
# Collecting pickleshare
#   Downloading pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Collecting prompt-toolkit<3.1.0,>=3.0.11
#   Downloading prompt_toolkit-3.0.36-py3-none-any.whl (386 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.4/386.4 kB 13.8 MB/s eta 0:00:00
# Collecting entrypoints
#   Downloading entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/lucia/mambaforge/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.0->sparqlkernel) (2.8.2)
# Collecting platformdirs>=2.5
#   Downloading platformdirs-2.6.2-py3-none-any.whl (14 kB)
# Collecting jupyter-server>=1.8
#   Downloading jupyter_server-2.0.6-py3-none-any.whl (363 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 364.0/364.0 kB 14.5 MB/s eta 0:00:00
# Collecting notebook-shim>=0.1.0
#   Downloading notebook_shim-0.2.2-py3-none-any.whl (13 kB)
# Collecting defusedxml
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting tinycss2
#   Downloading tinycss2-1.2.1-py3-none-any.whl (21 kB)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 3.8 MB/s eta 0:00:00
# Collecting mistune<3,>=2.0.3
#   Downloading mistune-2.0.4-py2.py3-none-any.whl (24 kB)
# Collecting pandocfilters>=1.4.1
#   Downloading pandocfilters-1.5.0-py2.py3-none-any.whl (8.7 kB)
# Collecting jupyterlab-pygments
#   Downloading jupyterlab_pygments-0.2.2-py2.py3-none-any.whl (21 kB)
# Collecting nbclient>=0.5.0
#   Downloading nbclient-0.7.2-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 5.5 MB/s eta 0:00:00
# Collecting markupsafe>=2.0
#   Downloading MarkupSafe-2.1.1-cp310-cp310-macosx_10_9_x86_64.whl (13 kB)
# Collecting bleach
#   Downloading bleach-5.0.1-py3-none-any.whl (160 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.9/160.9 kB 9.3 MB/s eta 0:00:00
# Collecting fastjsonschema
#   Downloading fastjsonschema-2.16.2-py3-none-any.whl (22 kB)
# Collecting jsonschema>=2.6
#   Downloading jsonschema-4.17.3-py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.4/90.4 kB 7.1 MB/s eta 0:00:00
# Collecting ptyprocess
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Collecting argon2-cffi-bindings
#   Downloading argon2_cffi_bindings-21.2.0-cp38-abi3-macosx_10_9_universal2.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: six in /Users/lucia/mambaforge/lib/python3.10/site-packages (from isodate->rdflib->sparqlkernel) (1.16.0)
# Collecting parso<0.9.0,>=0.8.0
#   Downloading parso-0.8.3-py2.py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 6.6 MB/s eta 0:00:00
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
#   Downloading pyrsistent-0.19.3-cp310-cp310-macosx_10_9_universal2.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.5/82.5 kB 5.3 MB/s eta 0:00:00
# Collecting attrs>=17.4.0
#   Downloading attrs-22.2.0-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 3.7 MB/s eta 0:00:00
# Collecting jupyter-server-terminals
#   Downloading jupyter_server_terminals-0.4.4-py3-none-any.whl (13 kB)
# Collecting anyio<4,>=3.1.0
#   Downloading anyio-3.6.2-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 kB 5.5 MB/s eta 0:00:00
# Collecting websocket-client
#   Downloading websocket_client-1.4.2-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.3/55.3 kB 4.8 MB/s eta 0:00:00
# Collecting jupyter-events>=0.4.0
#   Downloading jupyter_events-0.6.2-py3-none-any.whl (18 kB)
# Collecting wcwidth
#   Downloading wcwidth-0.2.5-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: cffi>=1.0.1 in /Users/lucia/mambaforge/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->sparqlkernel) (1.15.1)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Collecting webencodings
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting pure-eval
#   Downloading pure_eval-0.2.2-py3-none-any.whl (11 kB)
# Collecting executing>=1.2.0
#   Downloading executing-1.2.0-py2.py3-none-any.whl (24 kB)
# Collecting asttokens>=2.1.0
#   Downloading asttokens-2.2.1-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: idna>=2.8 in /Users/lucia/mambaforge/lib/python3.10/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->sparqlkernel) (3.4)
# Collecting sniffio>=1.1
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: pycparser in /Users/lucia/mambaforge/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->sparqlkernel) (2.21)
# Collecting rfc3986-validator>=0.1.1
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Collecting python-json-logger>=2.0.4
#   Downloading python_json_logger-2.0.4-py3-none-any.whl (7.8 kB)
# Collecting rfc3339-validator
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting pyyaml>=5.3
#   Downloading PyYAML-6.0-cp310-cp310-macosx_10_9_x86_64.whl (197 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.6/197.6 kB 11.6 MB/s eta 0:00:00
# Collecting webcolors>=1.11
#   Downloading webcolors-1.12-py3-none-any.whl (9.9 kB)
# Collecting uri-template
#   Downloading uri_template-1.2.0-py3-none-any.whl (10 kB)
# Collecting jsonpointer>1.13
#   Downloading jsonpointer-2.3-py2.py3-none-any.whl (7.8 kB)
# Collecting isoduration
#   Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting fqdn
#   Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting arrow>=0.15.0
#   Downloading arrow-1.2.3-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 4.9 MB/s eta 0:00:00
# Building wheels for collected packages: sparqlkernel
#   Building wheel for sparqlkernel (setup.py) ... done
#   Created wheel for sparqlkernel: filename=sparqlkernel-1.3.0-py3-none-any.whl size=33650 sha256=f2dcaf3b88372b46f5128424cf98ad6ddc49d8aded0d76c13813e26c40df889e
#   Stored in directory: /Users/lucia/Library/Caches/pip/wheels/e2/14/83/aa226bb782bffb67a2a9b865c0758624d6e56d96145b0b0b77
# Successfully built sparqlkernel
# Installing collected packages: webencodings, wcwidth, Send2Trash, pure-eval, ptyprocess, pickleshare, mistune, ipython-genutils, fastjsonschema, executing, backcall, appnope, websocket-client, webcolors, uri-template, traitlets, tornado, tinycss2, soupsieve, sniffio, rfc3986-validator, rfc3339-validator, pyzmq, pyyaml, python-json-logger, pyrsistent, pygments, psutil, prompt-toolkit, prometheus-client, platformdirs, pexpect, parso, pandocfilters, packaging, nest-asyncio, markupsafe, jupyterlab-pygments, jsonpointer, fqdn, entrypoints, defusedxml, decorator, debugpy, bleach, attrs, asttokens, terminado, stack-data, matplotlib-inline, jupyter-core, jsonschema, jinja2, jedi, comm, beautifulsoup4, arrow, argon2-cffi-bindings, anyio, SPARQLWrapper, nbformat, jupyter-server-terminals, jupyter-client, isoduration, ipython, argon2-cffi, nbclient, ipykernel, nbconvert, jupyter-events, jupyter-server, notebook-shim, nbclassic, notebook, sparqlkernel
# Successfully installed SPARQLWrapper-2.0.0 Send2Trash-1.8.0 anyio-3.6.2 appnope-0.1.3 argon2-cffi-21.3.0 argon2-cffi-bindings-21.2.0 arrow-1.2.3 asttokens-2.2.1 attrs-22.2.0 backcall-0.2.0 beautifulsoup4-4.11.1 bleach-5.0.1 comm-0.1.2 debugpy-1.6.5 decorator-5.1.1 defusedxml-0.7.1 entrypoints-0.4 executing-1.2.0 fastjsonschema-2.16.2 fqdn-1.5.1 ipykernel-6.20.1 ipython-8.8.0 ipython-genutils-0.2.0 isoduration-20.11.0 jedi-0.18.2 jinja2-3.1.2 jsonpointer-2.3 jsonschema-4.17.3 jupyter-client-7.4.8 jupyter-core-5.1.3 jupyter-events-0.6.2 jupyter-server-2.0.6 jupyter-server-terminals-0.4.4 jupyterlab-pygments-0.2.2 markupsafe-2.1.1 matplotlib-inline-0.1.6 mistune-2.0.4 nbclassic-0.4.8 nbclient-0.7.2 nbconvert-7.2.7 nbformat-5.7.3 nest-asyncio-1.5.6 notebook-6.5.2 notebook-shim-0.2.2 packaging-23.0 pandocfilters-1.5.0 parso-0.8.3 pexpect-4.8.0 pickleshare-0.7.5 platformdirs-2.6.2 prometheus-client-0.15.0 prompt-toolkit-3.0.36 psutil-5.9.4 ptyprocess-0.7.0 pure-eval-0.2.2 pygments-2.14.0 pyrsistent-0.19.3 python-json-logger-2.0.4 pyyaml-6.0 pyzmq-25.0.0 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 sniffio-1.3.0 soupsieve-2.3.2.post1 sparqlkernel-1.3.0 stack-data-0.6.2 terminado-0.17.1 tinycss2-1.2.1 tornado-6.2 traitlets-5.8.1 uri-template-1.2.0 wcwidth-0.2.5 webcolors-1.12 webencodings-0.5.1 websocket-client-1.4.2

# %%
# !jupyter sparqlkernel install
# Out:
# [SparqlKernelInstall] Installing SPARQL kernel
# [SparqlKernelInstall] Installing kernel spec
# [SparqlKernelInstall] Removing existing kernelspec in /usr/local/share/jupyter/kernels/sparql
# [SparqlKernelInstall] Installed kernelspec sparql in /usr/local/share/jupyter/kernels/sparql
# [SparqlKernelInstall] Installed into /usr/local/share/jupyter/kernels/sparql
# [SparqlKernelInstall] Installing CSS
# Traceback (most recent call last):
#   File "/Users/lucia/mambaforge/bin/jupyter-sparqlkernel", line 8, in <module>
#     sys.exit(main())
#   File "/Users/lucia/mambaforge/lib/python3.10/site-packages/sparqlkernel/__main__.py", line 31, in main
#     SparqlKernelApp.launch_instance()
#   File "/Users/lucia/mambaforge/lib/python3.10/site-packages/traitlets/config/application.py", line 1041, in launch_instance
#     app.start()
#   File "/Users/lucia/mambaforge/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 708, in start
#     return self.subapp.start()
#   File "/Users/lucia/mambaforge/lib/python3.10/site-packages/sparqlkernel/install.py", line 207, in start
#     destd = os.path.join( notebook.DEFAULT_STATIC_FILES_PATH, 'custom' )
# AttributeError: module 'notebook' has no attribute 'DEFAULT_STATIC_FILES_PATH'

# %% [markdown]
# Configuration of the UNIPROT endpoint

# %%
# %endpoint https://sparql.uniprot.org/sparql
# Out:
# UsageError: Line magic function `%endpoint` not found.

# %%
# %format JSON
